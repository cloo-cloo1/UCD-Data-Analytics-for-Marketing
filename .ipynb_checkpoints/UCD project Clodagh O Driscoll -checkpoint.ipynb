# %% [markdown]
# # 1. Data
# Location of the csv dataset ' Amazing Cart EU' https://www.artofvisualization.com/pages/tableau
#
# Location of the API countries https://api.covid19api.com/summary

# %% [markdown]
# # 2. Importing

# %% [markdown]
# Importing packages

# %%
import pandas as pd
import os 
import requests
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.dates as mdates
import numpy as np

# %% [markdown]
# ### Custom Function

# %%
def Dataframe(a):  # creating a custom function to export dataframe to csv
    answer = a.to_csv('Project_Output.csv')     # this function is used instead of typing the .to_csv code everytime i want to extract dataframes to excel
    return answer

# %% [markdown]
# ### Importing data from csv

# %%
# Finding current path
os.getcwd()

# Assigning csv files to dataframes
order_list = pd.read_csv('list_of_orders.csv' , parse_dates=['Order Date','Ship Date']) #reading list of orders file
order_breakdown = pd.read_csv('order_breakdown.csv') #reading list of orders file
order_breakdown
# Out:
#              Order ID                           Product Name  Discount  Sales  \
# 0     BN-2011-7407039            Enermax Note Cards, Premium       0.5   45.0
# 1     AZ-2011-9050313     Dania Corner Shelving, Traditional       0.0  854.0
# 2     AZ-2011-6674300  Binney & Smith Sketch Pad, Easy-Erase       0.0  140.0
# 3     BN-2011-2819714             Boston Markers, Easy-Erase       0.5   27.0
# 4     BN-2011-2819714            Eldon Folders, Single Width       0.5   17.0
# ...               ...                                    ...       ...    ...
# 8042   AZ-2014-766953   Ikea Stackable Bookrack, Traditional       0.0  245.0
# 8043  BN-2014-4140795      BIC Pencil Sharpener, Fluorescent       0.5   30.0
# 8044  BN-2014-4140795          Avery Binder Covers, Recycled       0.5   23.0
# 8045  BN-2014-4140795                    StarTech Phone, Red       0.5  108.0
# 8046   AZ-2014-766953              Motorola Audio Dock, VoIP       0.0  867.0
#
#       Profit  Quantity         Category Sub-Category
# 0      -26.0         3  Office Supplies        Paper
# 1      290.0         7        Furniture    Bookcases
# 2       21.0         3  Office Supplies          Art
# 3      -22.0         2  Office Supplies          Art
# 4       -1.0         2  Office Supplies      Storage
# ...      ...       ...              ...          ...
# 8042    91.0         2        Furniture    Bookcases
# 8043   -10.0         2  Office Supplies          Art
# 8044    -6.0         4  Office Supplies      Binders
# 8045   -19.0         3       Technology     Machines
# 8046   251.0         5       Technology       Phones
#
# [8047 rows x 8 columns]

# %% [markdown]
# ### Merging Dataframe

# %%
# Merging dataframes from csv
combined = pd.merge(order_list, order_breakdown, how='inner', on = 'Order ID')
combined.head()
# Out:
#           Order ID Order Date    Customer Name    City CountryCode   Region  \
# 0  AZ-2011-4827146 2011-11-01  Faith Greenwood  Vienna          AT  Central
# 1  AZ-2011-4827146 2011-11-01  Faith Greenwood  Vienna          AT  Central
# 2  AZ-2011-5960662 2011-01-14        Ella Troy  Vienna          AT  Central
# 3  AZ-2011-5960662 2011-01-14        Ella Troy  Vienna          AT  Central
# 4  AZ-2011-5960662 2011-01-14        Ella Troy  Vienna          AT  Central
#
#        Segment  Ship Date  Order Shipment TimeFrame Ship Mode   State  \
# 0     Consumer 2011-01-15                         4   Economy  Vienna
# 1     Consumer 2011-01-15                         4   Economy  Vienna
# 2  Home Office 2011-01-19                         5   Economy  Vienna
# 3  Home Office 2011-01-19                         5   Economy  Vienna
# 4  Home Office 2011-01-19                         5   Economy  Vienna
#
#                     Product Name  Discount  Sales  Profit  Quantity  \
# 0     Boston Canvas, Fluorescent       0.0   55.0    10.0         1
# 1      Smead Trays, Single Width       0.0   97.0    31.0         2
# 2   Xerox Message Books, Premium       0.0  224.0   103.0        11
# 3   StarTech Card Printer, White       0.0  486.0    78.0         3
# 4  Apple Headset, with Caller ID       0.0  440.0    66.0         6
#
#           Category Sub-Category
# 0  Office Supplies          Art
# 1  Office Supplies      Storage
# 2  Office Supplies        Paper
# 3       Technology     Machines
# 4       Technology       Phones

# %% [markdown]
# ### Importing data from API

# %%
#Retrieving country codes & name from API
cv19 = requests.get('https://api.covid19api.com/summary')
cv19 = cv19.json()
df = pd.DataFrame(cv19['Countries'])
countries = df[["Country","CountryCode"]]
countries.head()
# Out:
#        Country CountryCode
# 0  Afghanistan          AF
# 1      Albania          AL
# 2      Algeria          DZ
# 3      Andorra          AD
# 4       Angola          AO

# %% [markdown]
# # 3. Preparation

# %% [markdown]
# #### Merging dataframes from csv & API

# %%
df_joined_table = pd.merge(combined,countries, on='CountryCode', how='left')
df_merged=df_joined_table[['Order ID','Order Date','Customer Name','City','Country','Region','Segment','Ship Date',
                  'Ship Mode','State','Product Name','Discount','Sales','Profit','Quantity','Category','Sub-Category', 'Order Shipment TimeFrame']]

#code to check the number of nulls in the dataset 
df_merged.isnull().sum() 

#UK did not have corresponding Country name , using code to replace the null values with 'United Kingdom'
df_merged = df_merged.replace(r'^\s*$', np.nan, regex=True)
df_merged.fillna('United Kingdom', inplace=True)
df_merged
# Out:
#              Order ID Order Date    Customer Name        City         Country  \
# 0     AZ-2011-4827146 2011-11-01  Faith Greenwood      Vienna         Austria
# 1     AZ-2011-4827146 2011-11-01  Faith Greenwood      Vienna         Austria
# 2     AZ-2011-5960662 2011-01-14        Ella Troy      Vienna         Austria
# 3     AZ-2011-5960662 2011-01-14        Ella Troy      Vienna         Austria
# 4     AZ-2011-5960662 2011-01-14        Ella Troy      Vienna         Austria
# ...               ...        ...              ...         ...             ...
# 8042  AZ-2014-8007090 2014-12-30   Mary Saterfiel    Plymouth  United Kingdom
# 8043   AZ-2014-157670 2014-12-30       Max Ludwig   Edinburgh  United Kingdom
# 8044   AZ-2014-766953 2014-12-31     Jose Gambino  Maidenhead  United Kingdom
# 8045   AZ-2014-766953 2014-12-31     Jose Gambino  Maidenhead  United Kingdom
# 8046  AZ-2014-1412225 2014-12-31      Leon Barnes   Worcester  United Kingdom
#
#        Region      Segment  Ship Date Ship Mode     State  \
# 0     Central     Consumer 2011-01-15   Economy    Vienna
# 1     Central     Consumer 2011-01-15   Economy    Vienna
# 2     Central  Home Office 2011-01-19   Economy    Vienna
# 3     Central  Home Office 2011-01-19   Economy    Vienna
# 4     Central  Home Office 2011-01-19   Economy    Vienna
# ...       ...          ...        ...       ...       ...
# 8042    North     Consumer 2015-03-01   Economy   England
# 8043    North  Home Office 2015-04-01   Economy  Scotland
# 8044    North    Corporate 2015-05-01   Economy   England
# 8045    North    Corporate 2015-05-01   Economy   England
# 8046    North     Consumer 2015-01-01  Priority   England
#
#                               Product Name  Discount  Sales  Profit  Quantity  \
# 0               Boston Canvas, Fluorescent       0.0   55.0    10.0         1
# 1                Smead Trays, Single Width       0.0   97.0    31.0         2
# 2             Xerox Message Books, Premium       0.0  224.0   103.0        11
# 3             StarTech Card Printer, White       0.0  486.0    78.0         3
# 4            Apple Headset, with Caller ID       0.0  440.0    66.0         6
# ...                                    ...       ...    ...     ...       ...
# 8042            Fellowes Box, Single Width       0.0   39.0     2.0         2
# 8043      Office Star Chairmat, Adjustable       0.0   68.0    27.0         1
# 8044  Ikea Stackable Bookrack, Traditional       0.0  245.0    91.0         2
# 8045             Motorola Audio Dock, VoIP       0.0  867.0   251.0         5
# 8046       Fellowes Shelving, Single Width       0.0  289.0    75.0         5
#
#              Category Sub-Category  Order Shipment TimeFrame
# 0     Office Supplies          Art                         4
# 1     Office Supplies      Storage                         4
# 2     Office Supplies        Paper                         5
# 3          Technology     Machines                         5
# 4          Technology       Phones                         5
# ...               ...          ...                       ...
# 8042  Office Supplies      Storage                         4
# 8043        Furniture       Chairs                         5
# 8044        Furniture    Bookcases                         5
# 8045       Technology       Phones                         5
# 8046  Office Supplies      Storage                         1
#
# [8047 rows x 18 columns]

# %% [markdown]
# ### checking for duplicates

# %%
Dataframe(df_merged) #extracting the merged dataframes to csv 
#After looking at the dataset there was no duplicates , no need to perform remove dpulicates

# %% [markdown]
# #### Ordering dataframe

# %%
df_merged.sort_values(by=['Order Date'], ascending=False)
df_merged.head()
# Out:
#           Order ID Order Date    Customer Name    City  Country   Region  \
# 0  AZ-2011-4827146 2011-11-01  Faith Greenwood  Vienna  Austria  Central
# 1  AZ-2011-4827146 2011-11-01  Faith Greenwood  Vienna  Austria  Central
# 2  AZ-2011-5960662 2011-01-14        Ella Troy  Vienna  Austria  Central
# 3  AZ-2011-5960662 2011-01-14        Ella Troy  Vienna  Austria  Central
# 4  AZ-2011-5960662 2011-01-14        Ella Troy  Vienna  Austria  Central
#
#        Segment  Ship Date Ship Mode   State                   Product Name  \
# 0     Consumer 2011-01-15   Economy  Vienna     Boston Canvas, Fluorescent
# 1     Consumer 2011-01-15   Economy  Vienna      Smead Trays, Single Width
# 2  Home Office 2011-01-19   Economy  Vienna   Xerox Message Books, Premium
# 3  Home Office 2011-01-19   Economy  Vienna   StarTech Card Printer, White
# 4  Home Office 2011-01-19   Economy  Vienna  Apple Headset, with Caller ID
#
#    Discount  Sales  Profit  Quantity         Category Sub-Category  \
# 0       0.0   55.0    10.0         1  Office Supplies          Art
# 1       0.0   97.0    31.0         2  Office Supplies      Storage
# 2       0.0  224.0   103.0        11  Office Supplies        Paper
# 3       0.0  486.0    78.0         3       Technology     Machines
# 4       0.0  440.0    66.0         6       Technology       Phones
#
#    Order Shipment TimeFrame
# 0                         4
# 1                         4
# 2                         5
# 3                         5
# 4                         5

# %% [markdown]
# # 4. Analysis

# %% [markdown]
# #### Creating conditional statement
# - *Creating new column to get difference between order date and shipping date*

# %%
def assign_Result(x):
    if (x == 2) or (x == 3) :
        return  'Priority Shipping'
    elif (x == 0) or (x == 1):
        return 'Next Day Shipping'
    elif x >= 4:
        return 'Standard Shipping'
    else:
        return 'Other'
df_merged['Shipping options'] = df_merged['Order Shipment TimeFrame'].apply(assign_Result)
#df_merged = df_merged.drop('Ship Mode', axis=1) # removing the 'Ship Mode' column
df_merged['Year'] = df_merged['Order Date'].dt.strftime('%Y')
df_merged['Month'] = df_merged['Order Date'].dt.strftime('%b')
df_merged['Month-Year'] = df_merged['Order Date'].dt.strftime('%m/%Y')
Dataframe(df_merged) #exporting the data without the 'ship mode' column
df_merged
# Out:
#              Order ID Order Date    Customer Name        City  Country  \
# 0     AZ-2011-4827146 2011-11-01  Faith Greenwood      Vienna  Austria
# 1     AZ-2011-4827146 2011-11-01  Faith Greenwood      Vienna  Austria
# 2     AZ-2011-5960662 2011-01-14        Ella Troy      Vienna  Austria
# 3     AZ-2011-5960662 2011-01-14        Ella Troy      Vienna  Austria
# 4     AZ-2011-5960662 2011-01-14        Ella Troy      Vienna  Austria
# ...               ...        ...              ...         ...      ...
# 8042  AZ-2014-8007090 2014-12-30   Mary Saterfiel    Plymouth      NaN
# 8043   AZ-2014-157670 2014-12-30       Max Ludwig   Edinburgh      NaN
# 8044   AZ-2014-766953 2014-12-31     Jose Gambino  Maidenhead      NaN
# 8045   AZ-2014-766953 2014-12-31     Jose Gambino  Maidenhead      NaN
# 8046  AZ-2014-1412225 2014-12-31      Leon Barnes   Worcester      NaN
#
#        Region      Segment  Ship Date Ship Mode     State  ...  Sales  Profit  \
# 0     Central     Consumer 2011-01-15   Economy    Vienna  ...   55.0    10.0
# 1     Central     Consumer 2011-01-15   Economy    Vienna  ...   97.0    31.0
# 2     Central  Home Office 2011-01-19   Economy    Vienna  ...  224.0   103.0
# 3     Central  Home Office 2011-01-19   Economy    Vienna  ...  486.0    78.0
# 4     Central  Home Office 2011-01-19   Economy    Vienna  ...  440.0    66.0
# ...       ...          ...        ...       ...       ...  ...    ...     ...
# 8042    North     Consumer 2015-03-01   Economy   England  ...   39.0     2.0
# 8043    North  Home Office 2015-04-01   Economy  Scotland  ...   68.0    27.0
# 8044    North    Corporate 2015-05-01   Economy   England  ...  245.0    91.0
# 8045    North    Corporate 2015-05-01   Economy   England  ...  867.0   251.0
# 8046    North     Consumer 2015-01-01  Priority   England  ...  289.0    75.0
#
#       Quantity         Category  Sub-Category Order Shipment TimeFrame  \
# 0            1  Office Supplies           Art                        4
# 1            2  Office Supplies       Storage                        4
# 2           11  Office Supplies         Paper                        5
# 3            3       Technology      Machines                        5
# 4            6       Technology        Phones                        5
# ...        ...              ...           ...                      ...
# 8042         2  Office Supplies       Storage                        4
# 8043         1        Furniture        Chairs                        5
# 8044         2        Furniture     Bookcases                        5
# 8045         5       Technology        Phones                        5
# 8046         5  Office Supplies       Storage                        1
#
#        Shipping options  Year Month Month-Year
# 0     Standard Shipping  2011   Nov    11/2011
# 1     Standard Shipping  2011   Nov    11/2011
# 2     Standard Shipping  2011   Jan    01/2011
# 3     Standard Shipping  2011   Jan    01/2011
# 4     Standard Shipping  2011   Jan    01/2011
# ...                 ...   ...   ...        ...
# 8042  Standard Shipping  2014   Dec    12/2014
# 8043  Standard Shipping  2014   Dec    12/2014
# 8044  Standard Shipping  2014   Dec    12/2014
# 8045  Standard Shipping  2014   Dec    12/2014
# 8046  Next Day Shipping  2014   Dec    12/2014
#
# [8047 rows x 22 columns]

# %% [markdown]
# #### Group by Country to aggregate sales

# %%
#The following code gets the top performing countries based on no. of orders
df_sales = df_merged.query('Year =="2014"')
df_sales_by_country = df_sales.groupby(['Country','Year']).agg({'Sales':'sum'}).sort_values(by=['Sales'], ascending=False)
df_sales_by_country
#Dataframe(df_sales_by_country)
# Out:
#                      Sales
# Country     Year
# France      2014  198260.0
# Germany     2014  150812.0
# Italy       2014   90263.0
# Spain       2014   77158.0
# Austria     2014   22777.0
# Netherlands 2014   19492.0
# Belgium     2014   16242.0
# Sweden      2014   15588.0
# Norway      2014   12887.0
# Switzerland 2014    7310.0
# Ireland     2014    6582.0
# Denmark     2014    2758.0
# Portugal    2014    1824.0
# Finland     2014    1134.0

# %% [markdown]
# ### Creating For Loop

# %%
# For loop to identify what customers have a profit of more than 1000 euros 
high_value_cust = []
for index,row in df_merged.iterrows():
    if row['Profit'] > 1000:
        high_value_cust.append([row['Customer Name'],row['Profit'],row['Country']])
    else:
        continue
for i in high_value_cust:
    print(i)
# Out:
# ['Lola Hughes', 1127.0, 'Austria']
# ["Maya O'Sullivan", 1868.0, 'France']
# ['Ashton Charles', 1518.0, 'France']
# ['Robert Neil', 1164.0, 'France']
# ['Jordan Peacock', 1189.0, 'France']
# ['Erick Tanner', 1019.0, 'France']
# ['Thomas McCallum', 1364.0, 'Germany']
# ['Morgan Dodd', 1112.0, 'Germany']
# ['Robert Ramsey', 1094.0, 'Germany']
# ['Milla Day', 1130.0, 'Germany']
# ['Nicole Carr', 1042.0, 'Germany']
# ['Hayley Baldwinson', 1151.0, 'Germany']
# ['Michael Flores', 1141.0, 'Italy']
# ['Angie Massengill', 1990.0, 'Italy']
# ['Alexander Bond', 2476.0, 'Spain']
# ['Catharine Robbins', 1445.0, 'Spain']
# ['Bianca Whitford', 1296.0, 'Spain']
# ['Eloise Sykes', 1015.0, 'Spain']
# ['Maynard Moorman', 1470.0, 'Spain']
# ['Joel Ortega', 1220.0, 'Spain']
# ['Phoebe Moore', 1041.0, 'Spain']
# ['Nancy Seay', 1050.0, 'Spain']
# ['Abby Mei', 1061.0, 'Switzerland']
# ['Natasha Sykes', 1759.0, nan]
# ['Molly Palmer', 1425.0, nan]
# ['Rachel Norton', 1528.0, nan]
# ['Harrison Cooke', 2461.0, nan]
# ['Lara Stoate', 1990.0, nan]
# ['Sarah Cross', 1041.0, nan]
# ['George Dawson', 1898.0, nan]
# ['Ashton Charles', 1698.0, nan]
# ['Jay Johnson', 1033.0, nan]
# ['Thomas Thompson', 1216.0, nan]
# ['Kyle Beard', 1420.0, nan]

# %% [markdown]
# Converting List into Dataframe

# %%
#This dataframe can be by CRM team to target high value customers with offers, promos etc 
df_high_value_customers = pd.DataFrame (high_value_cust, columns = ['Customer Name','Profit','Country'])
df_high_value_customers.head()
Dataframe(df_high_value_customers) #writing the dataframe to a csv which can be next to the CRM team

# %% [markdown]
# # 5. Visualisation

# %% [markdown]
# ### Top 10 Countries with highest sales

# %%
df_top_sales_by_country = df_merged.groupby(['Country'], as_index=True).agg({'Sales':'sum'}).sort_values(by=['Sales'], ascending=False).head(10)
df_top_sales_by_country
# Out:
#                 Sales
# Country
# France       609683.0
# Germany      488681.0
# Italy        252742.0
# Spain        249402.0
# Austria       79382.0
# Netherlands   70313.0
# Belgium       42320.0
# Sweden        30490.0
# Switzerland   24874.0
# Finland       20702.0

# %%
sns.set(font_scale=1.5)
import matplotlib.pyplot as plt
p = sns.barplot(
    x="Country", 
    y="Sales", 
    data=df_top_sales_by_country.reset_index(), 
    estimator=sum, 
    ci=None
    );
plt.rcParams['figure.figsize'] = [15, 5]
p.bar_label(p.containers[0], fontsize=15)
#p.legend(fontsize=25)
p.set_xlabel("Country", fontsize = 20, weight='bold')
p.set_ylabel("Total Sales", fontsize = 20,  weight='bold')
p.set_title("Top 10 Countries by Total Sales ", fontsize = 20, weight='bold')
#plt.rcParams['figure.figsize'] = [40, 15]
#plt.figure(figsize=(15,8))
#plt.xticks(rotation = 45)
plt.show()
fig = p.get_figure()
fig.savefig("Top 10 Countries by Sales.png")

# %% [markdown]
# ### Top 10 Countries by no. of orders

# %%
#df_sales = df_merged[df_merged["Category"].str.contains("Office Supplies")]
#df_sales = df_merged.query('Year =="2014"')
df_top_orders_by_country = df_merged.groupby(['Country'], as_index=True).agg({'Quantity':'sum'}).sort_values(by=['Quantity'], ascending=False).head(10)
#df_top_sales_by_country["Rank"] = df_top_sales_by_country["Sales"].rank()
#df_top_sales_by_country.sort_values("Rank", inplace = True)
df_top_orders_by_country
# Out:
#              Quantity
# Country
# France           7329
# Germany          6179
# Italy            3612
# Spain            2881
# Netherlands      1526
# Austria           973
# Sweden            753
# Belgium           532
# Ireland           392
# Switzerland       308

# %%
sns.set(font_scale=2)
import matplotlib.pyplot as plt
p = sns.barplot(
    x="Country", 
    y="Quantity", 
    data=df_top_orders_by_country.reset_index(), 
    estimator=sum, 
    ci=None
    );
plt.rcParams['figure.figsize'] = [20, 10]
p.bar_label(p.containers[0], fontsize=15)
#p.legend(fontsize=25)
p.set_xlabel("Country", fontsize = 20, weight='bold')
p.set_ylabel("No. of Orders", fontsize = 20,  weight='bold')
p.set_title("Top 10 Countries by No. of Orders ", fontsize = 20, weight='bold')
#plt.rcParams['figure.figsize'] = [40, 15]
#plt.figure(figsize=(15,8))
#plt.xticks(rotation = 45)
plt.show()
fig = p.get_figure()
fig.savefig("Top 10 Countries No. of Orders .png")

# %%
import matplotlib.pyplot as plt
sns.countplot(data=df_merged, x="Shipping options", hue="Year") 
plt.rcParams['figure.figsize'] = [20, 25]
plt.show()

# %%
import matplotlib.pyplot as plt
p = sns.barplot(
    x="Shipping options", 
    y="Quantity", 
    data=df_merged, 
    estimator=sum, 
    ci=None, 
    hue="Year",
    );
plt.rcParams['figure.figsize'] = [20, 25]
plt.show()

# %%
sns.lineplot(x="Month-Year", y="Quantity", hue="Category", data=df_merged, ci=None)
plt.xticks(rotation = 90)
plt.rcParams['figure.figsize'] = [60, 5]
plt.show()

# %% [markdown]
# ### Shipping options by country

# %%
# Define a query string with isin
subset = df_merged['Country'].isin(["Ireland"])
# filter specific columns
cols = ['Country', 'Quantity', 'Year', 'Shipping options']
country_df = df_merged.loc[subset, cols]
country_df.head()
#Dataframe(country_df)
# Out:
#       Country  Quantity  Year   Shipping options
# 4079  Ireland         3  2011  Standard Shipping
# 4080  Ireland         7  2011  Standard Shipping
# 4081  Ireland         3  2011  Standard Shipping
# 4082  Ireland         5  2011  Standard Shipping
# 4083  Ireland         2  2011  Standard Shipping

# %% [markdown]
# ### Chart to show to the shipping options by country

# %%
sns.set(font_scale=2)
sns.color_palette("Set2")
p = sns.barplot(
    x="Shipping options", 
    y="Quantity", 
    data=country_df, 
    estimator=sum, 
    ci=None, 
    hue="Year",
    );
p.legend(fontsize=25)
p.set_xlabel("Shipping Options", fontsize = 25, weight='bold')
p.set_ylabel("No. of Orders", fontsize = 25,  weight='bold')
p.set_title("No. of orders by shipping options in Ireland ", fontsize = 25, weight='bold')
plt.rcParams['figure.figsize'] = [40, 15]
plt.show()
fig = p.get_figure()
fig.savefig("Shipping_options_Austria.png")
